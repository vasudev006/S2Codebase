# %% [markdown]
# <a href="https://colab.research.google.com/github/vasudev006/S2Codebase/blob/main/EXPERIMENT_NO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment No.3
#
# Evaluating gradient of a scalar field and visualise

# %% [markdown]
# **Case**Find the gradient of the scalar $f=x^2+y^2+z^2$ and plot the gradient field.

# %% [markdown]
# **Solution**
#
# Evaluating the gradient of the scalar field

# %%
import sympy as sp

#Define the symbols
x,y,z = sp.symbols('x,y,z')

#Define the scalar field
scalar_field=x**2 + y**2 + z**2 #Example scalar field
scalar_field
# Out:
# x**2 + y**2 + z**2

# %%
#Compute the gradient
gradient=sp.Matrix([sp.diff(scalar_field,var) for var in (x,y,z)])
print("The gradient of the scalar field is")
gradient
# Out:
# The gradient of the scalar field is
# Matrix([
# [2*x],
# [2*y],
# [2*z]])

# %% [markdown]
# #Plotting gradient of the scalar field

# %%
import numpy as np
import matplotlib.pyplot as plt

#Define a grid of points where you wnt to evaluate the gradient
x_vals=np.linspace(-10,10,20)
y_vals=np.linspace(-10,10,20)
z_val=0 #For 2d visualisation in the z=0 plane

X,Y =np.meshgrid(x_vals,y_vals)

#Initialise arrays to store gradient components
U=np.zeros_like(X,dtype=float)
V=np.zeros_like(X,dtype=float)

#Evaluate the gradient at each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated=gradient.subs({x:X[i,j],y:Y[i,j],z:z_val})
    U[i,j]=float(grad_evaluated[0])
    V[i,j]=float(grad_evaluated[1])

#Plot the gradient vectors using matplotlib
fig,ax=plt.subplots()
ax.quiver(X,Y,U,V)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient vectors of the scalar field')
plt.show()

# %%
import sympy as sp
#Define the symbols
x,y=sp.symbols('x y')

#Define the scalar field
scalar_field1=100*sp.exp(-(x**2+y**2)/2) #Example scalar field
scalar_field1
# Out:
# 100*exp(-x**2/2 - y**2/2)

# %%
#Compute the gradient
grad=sp.Matrix([sp.diff(scalar_field1,var) for var in (x,y)])
print("The gradient of the scalar field is")
grad
# Out:
# The gradient of the scalar field is
# Matrix([
# [-100*x*exp(-x**2/2 - y**2/2)],
# [-100*y*exp(-x**2/2 - y**2/2)]])

# %%
#Creating a contour plot pof the temperature distribution
plt.contourf(X,Y,T,levels=10,cmap='inferno')
plt.colorbar(label='Temperature(°C)')
plt.title('Temperature distribution T(x,y)')
plt.xlabel('x(meters)')
plt.ylabel('Y')
plt.title('Temperature distribution')
plt.show()

# %%
#Define the region of the plate
x_values=np.linspace(-5,5,20)
y_values=np.linspace(-5,5,20)
X,Y =np.meshgrid(x_values,y_values)

#Initialise arrays to store gradient components
U=np.zeros_like(X,dtype=float)
V=np.zeros_like(Y,dtype=float)


#Evaluatre the gradient a each point
for i in range(X.shape[0]):
  for j in range(X.shape[1]):
    grad_evaluated=grad.subs({x:X[i,j],y:Y[i,j]})
    U[i,j]=float(grad_evaluated[0])
    V[i,j]=float(grad_evaluated[1])

#Plot the gradient vectors matplotlib
fig,ax=plt.subplots()
ax.quiver(X,Y,U,V)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_title('Gradient vectors of the scalar field')
plt.show()
